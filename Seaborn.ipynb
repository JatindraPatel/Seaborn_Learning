# %% [markdown]
# <a href="https://colab.research.google.com/github/JatindraPatel/Seaborn_Learning/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SEABORN** :-

# %% [markdown]
# Seaborn is a Python data-visualization library built on top of Matplotlib.
#
#
# It makes creating beautiful, statistical, and customized graphs much easier and faster.

# %% [markdown]
# **⭐ Key Features of Seaborn**
#
# High-level interface → easier and cleaner than Matplotlib.
#
#
#
# Beautiful default themes → your graphs look professional automatically.
#
# Supports statistical plots → regression plots, distribution plots, heatmaps, etc.
#
# Integrates well with pandas DataFrames.

# %% [markdown]
# **📊 Common Plots in Seaborn**
#
# sns.lineplot() → line chart
#
# sns.barplot() → bar chart
#
# sns.countplot() → count/frequency chart
#
# sns.heatmap() → correlation or matrix heatmap
#
# sns.distplot() / sns.histplot() → distributions
#
# sns.boxplot() → box & whisker plot
#
# sns.pairplot() → multiple relationships visualization
#
# sns.regplot() → regression trend line

# %% [markdown]
# **🎯 Why Use Seaborn**
#
# Less code than Matplotlib
#
# Better colors and styling
#
# Great for statistical data analysis
#
# Works perfectly with DataFrames (df)

# %% [markdown]
# **Difference Between Seaborn and Matplotlib**
#
#
# | Feature                   | **Matplotlib**                   | **Seaborn**                                                                   |
# | ------------------------- | -------------------------------- | ----------------------------------------------------------------------------- |
# | **Level**                 | Low-level                        | High-level                                                                    |
# | **Ease of Use**           | More code, manual styling        | Easy, automatic styling                                                       |
# | **Default Look**          | Basic, plain                     | Beautiful & modern                                                            |
# | **Focus**                 | General plotting                 | Statistical plotting                                                          |
# | **Best For**              | Custom plots, full control       | Quick, good-looking plots                                                     |
# | **Works With DataFrames** | Not very smooth                  | Very smooth (built for DataFrames)                                            |
# | **Plot Types**            | Basic plots (line, bar, scatter) | Advanced statistical plots (heatmap, pairplot, distplot, violinplot, regplot) |
# | **Customization**         | Very high but requires more code | High but simpler                                                              |
# | **Built On**              | Base library                     | Built on top of Matplotlib                                                    |

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5])
plt.show()
# Out:
# /tmp/ipython-input-4140046053.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5],hist=False)
plt.show()
# Out:
# /tmp/ipython-input-819044252.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5],hist=False)

# %%
# Univariant :-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns = [col.capitalize() for col in df.columns]

# %%
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['Total_bill'].max()
# Out:
# 50.81

# %%
df['Total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df['Total_bill'].min()
# Out:
# 3.07

# %%
sns.distplot(df['Total_bill'])
plt.show()
# Out:
# /tmp/ipython-input-606440632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_bill'])

# %%
sns.histplot(df['Total_bill'])
plt.show()

# %%
sns.distplot(df['Tip'])
plt.show()
# Out:
# /tmp/ipython-input-1986124094.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tip'])

# %%
# plt.style.use('tableau-colorblind10')
sns.distplot(df['Tip'],kde=False)
plt.show()
# Out:
# /tmp/ipython-input-2199950028.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tip'],kde=False)

# %%
sns.distplot(df['Tip'],kde=False,bins=10)
plt.show()
# Out:
# /tmp/ipython-input-400656482.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tip'],kde=False,bins=10)

# %%
import matplotlib.style as style
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Relational/ Scatter Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.relplot(x='Total_bill',y='Tip',data=df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.relplot(x='Total_bill',y='Tip',hue='Smoker',data=df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.relplot(x='Total_bill',y='Tip',hue='Smoker',style='Sex',data=df)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.relplot(x='Total_bill',y='Tip',hue='Smoker',style='Sex',size='Day',data=df)
plt.show()

# %% [markdown]
# # **26-11-2025**

# %% [markdown]
# # Box-Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.boxplot(df['Tip'])
# Out:
# <Axes: ylabel='Tip'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.boxplot(df['Total_bill'])
# Out:
# <Axes: ylabel='Total_bill'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-talk')

sns.boxplot(x='Day',y='Total_bill',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %% [markdown]
# # **27-11-2025**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(df['Tip'])
# Out:
# <Axes: ylabel='Tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(x='Sex',y='Total_bill',kind='violin',hue="Day",data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(x='Day',y='Total_bill',kind='violin',hue="Sex",data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(x='Day',y='Total_bill',kind='violin',hue="Sex",split=True,data=df)

# %% [markdown]
# # **Bar**

# %%
sns.catplot(x='Smoker',y='Tip',hue='Sex',kind='bar',data=df)

# %%
sns.barplot(x='Smoker',y='Tip',data=df)
# Out:
# <Axes: xlabel='Smoker', ylabel='Tip'>

# %%
sns.barplot(x='Smoker',y='Tip',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Smoker', ylabel='Tip'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.catplot(x='Smoker',y='Total_bill',hue='Sex',kind='bar',estimator=np.var,data=df)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.catplot(x='Smoker',y='Total_bill',hue='Sex',kind='bar',estimator=np.std,data=df)

# %%
sns.catplot(x='Day',hue='Sex',kind='count',data=df)

# %%
sns.countplot(x='Day',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
sns.catplot(x='Day',kind='count',data=df)
